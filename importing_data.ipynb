# %%
#import the package "Pandas" into Jupyter Notebook
import pandas as pd

# %%
#We import the stock data of Facebook and Microsoft into Jupyter Notebook. The CSV file is located in the folder called "data".
#We then name the DataFrame name as 'fb' and'ms'.
fb = pd.read_csv("data/facebook.csv")
ms = pd.read_csv("data/microsoft.csv")

# %%
# run this cell to ensure both companies' stock data is imported
print(f"ms: {ms.iloc[0,1]}")
print(f"fb: {fb.iloc[0,1]}")
# Out:
# ms: 46.73
# fb: 20.4
